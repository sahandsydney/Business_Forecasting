# %%
import pandas as pd
import matplotlib as plt

# %%
dataframe_stocks = pd.read_csv("..\data\ADANIPORTS.csv")

# %%
df_corr = dataframe_stocks[['High', 'Low']]
corr_mat = df_corr.corr() 
import seaborn as sns
sns.heatmap(corr_mat)
# Out:
# <AxesSubplot:>

# %%
balancesheets = pd.read_csv("..\\data\\adani_balance_sheet_full.csv")
balancesheets
# Out:
#     Balance Sheet of Adani Ports and Special Economic Zone (in Rs. Cr.)  \
# 0                                                  NaN
# 1                             EQUITIES AND LIABILITIES
# 2                                                  NaN
# 3                                  SHAREHOLDER'S FUNDS
# 4                                                  NaN
# ..                                                 ...
# 123                                CURRENT INVESTMENTS
# 124                                                NaN
# 125            Current Investments Quoted Market Value
# 126                                                NaN
# 127            Current Investments Unquoted Book Value
#
#     22-Mar  21-Mar 20-Mar  19-Mar 18-Mar  17-Mar 16-Mar  15-Mar 14-Mar  \
# 0      NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN
# 1      NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN
# ...

# %%
balancesheets = balancesheets.dropna(how="any")
balancesheets.head(7)
# Out:
#    Balance Sheet of Adani Ports and Special Economic Zone (in Rs. Cr.)  \
# 5                                Equity Share Capital
# 7                                 Total Share Capital
# 9                                Reserves and Surplus
# 11                         Total Reserves and Surplus
# 13                           Total Shareholders Funds
# 17                               Long Term Borrowings
# 19                     Deferred Tax Liabilities [Net]
#
#       22-Mar    21-Mar    20-Mar    19-Mar    18-Mar    17-Mar    16-Mar  \
# 5     422.47    406.35    406.35    414.19    414.19    414.19    414.19
# 7     537.82    512.18    503.44    514.13    505.88    498.31    414.19
# 9   25993.26   21228.4  19292.29   19911.6  17703.19  16284.78  13151.62
# 11  25993.26   21228.4  19292.29   19911.6  17703.19  16284.78  13151.62
# 13  26531.08  21740.58  19795.73  20425.73  18209.07  16783.09  13565.81
# 17   40511.3  30844.29  24540.66  17982.19   18748.1  16076.45  10247.05
# ...

# %%
balancesheets = balancesheets.transpose()
balancesheets.head(10)
# Out:
#                                                                      5    \
# Balance Sheet of Adani Ports and Special Econom...  Equity Share Capital
# 22-Mar                                                            422.47
# 21-Mar                                                            406.35
# 20-Mar                                                            406.35
# 19-Mar                                                            414.19
# 18-Mar                                                            414.19
# 17-Mar                                                            414.19
# 16-Mar                                                            414.19
# 15-Mar                                                            414.01
# 14-Mar                                                            414.01
#
#                                                                     7    \
# Balance Sheet of Adani Ports and Special Econom...  Total Share Capital
# ...

# %%
balancesheets = balancesheets.rename(columns= lambda x: x)
balancesheets.head()
# Out:
#                                                                      5    \
# Balance Sheet of Adani Ports and Special Econom...  Equity Share Capital
# 22-Mar                                                            422.47
# 21-Mar                                                            406.35
# 20-Mar                                                            406.35
# 19-Mar                                                            414.19
#
#                                                                     7    \
# Balance Sheet of Adani Ports and Special Econom...  Total Share Capital
# 22-Mar                                                           537.82
# 21-Mar                                                           512.18
# 20-Mar                                                           503.44
# 19-Mar                                                           514.13
#
#                                                                      9    \
# ...
